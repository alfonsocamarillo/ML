# %% [markdown]
# TensorFlow en Python:
# Ejemplo de uso en Python:
# Aquí tienes un ejemplo simple de cómo usar TensorFlow en Python para crear y entrenar un modelo de red neuronal:

# %% [markdown]
# 1. Instalación:
# Puedes instalar TensorFlow en Python utilizando pip:

# %%
pip install tensorflow
# Out:
# ...
#
# ...

# %% [markdown]
# Código del ejemplo explicado de TensorFlow
# Paso 1. Importar las librerías:

# %% [markdown]
# import pandas as pd
# import seaborn as sns
# import matplotlib.pyplot as plt
# import tensorflow as tf

# %%
Paso 2. Obtención de los datos

# %%
#El archivo está disponible en: https://drive.google.com/file/d/1InzN9ULPJJvPEgy4kslLJMj2zKOq20P8/view?usp=sharing
print ("Leyendo CSV")
#temperature_df = pd.read_csv("celsius_a_fahrenheit.csv")
temperature_df = pd.read_csv("C:/Users/LAZARO/OneDrive/Escritorio/Aula Virtual/GEM/00006 Programación con Python 140324 040424/Sesion 6/celsius_a_fahrenheit.csv")

# Visualización
sns.scatterplot(temperature_df)
plt.show()
# Out:
# Leyendo CSV
